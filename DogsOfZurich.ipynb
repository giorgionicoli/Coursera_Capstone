# %%
import pandas as pd
import numpy as np

# %%
link = 'https://data.stadt-zuerich.ch/dataset/sid_stapo_hundebestand/download/20210301_hundehalter.csv'
df = pd.read_csv(link)

# %%
df.head()
# Out:
#    HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER             RASSE1  \
# 0     155048  41-50          w          10            101    Mischling gross
# 1     119231  71-80          w          10            101   Golden Retriever
# 2     146137  41-50          w          10            101         Dalmatiner
# 3      83856  61-70          w          10            101      Tibet Terrier
# 4     118377  31-40          m          10            101  Deutscher Schäfer
#
#   RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  GEBURTSJAHR_HUND  \
# 0              NaN    NaN               NaN         I              2019
# 1              NaN    NaN               NaN         I              2011
# 2              NaN    NaN               NaN         I              2014
# 3              NaN    NaN               NaN         K              2012
# 4              NaN    NaN               NaN         I              2013
#
#   GESCHLECHT_HUND     HUNDEFARBE
# 0               m     grau/braun
# ...

# %%
df.groupby('STADTKREIS').count()
# Out:
#             HALTER_ID  ALTER  GESCHLECHT  STADTQUARTIER  RASSE1  \
# STADTKREIS
# 1                 130    130         130            130     130
# 2                 836    836         836            836     836
# 3                 767    767         767            767     767
# 4                 450    450         450            450     450
# 5                 290    290         290            290     290
# 6                 596    596         596            596     596
# 7                1168   1168        1168           1168    1168
# 8                 462    462         462            462     462
# 9                1065   1065        1065           1065    1065
# 10                758    758         758            758     758
# 11               1434   1434        1434           1434    1434
# 12                618    618         618            618     618
#
#             RASSE1_MISCHLING  RASSE2  RASSE2_MISCHLING  RASSENTYP  \
# STADTKREIS
# ...

# %%
zh_dogs = df[['HALTER_ID']]

# %%
CLIENT_ID = '1DWACJNZAKBZMSLXJM3APID2MTPPKML3SILTH5G4ZFY4WMZU' # your Foursquare ID
CLIENT_SECRET = 'IBETIAPPXZPUDLWO450G13RBFSCZQRXAO3ZEQXKHQXUVO35F' # your Foursquare Secret
ACCESS_TOKEN = '2QKC1QYY2AYW4AQS40VN5PPIWHJ3D4AEF2VVCW5MILGAZSLR' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
CLIENT_ID = '****' # your Foursquare ID
CLIENT_SECRET = '****' # your Foursquare Secret
ACCESS_TOKEN = '****' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
